# %% [markdown]
# <!-- @format -->
#
# # 05 - Final Evaluation & Visualization
#
# Notebook này dành cho đánh giá cuối cùng và vẽ biểu đồ đưa vào báo cáo.

# %% [markdown]
# <!-- @format -->
#
# ## Checklist
#
# - Đánh giá model tốt nhất trên test set
# - Vẽ actual vs predicted
# - Vẽ residual plot
# - Phân tích feature importance
# - Tổng hợp insight để viết báo cáo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: import hàm evaluate và đọc kết quả model cuối

# %%
# TODO: tính metric cuối cùng trên test set chưa thấy

# %%
# TODO: vẽ actual vs predicted

# %%
# TODO: vẽ residual plot

# %%
# TODO: vẽ feature importance nếu model hỗ trợ

# %%
# TODO: export bảng kết quả và hình ra reports/
